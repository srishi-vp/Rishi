# %% [markdown]
# <a href="https://colab.research.google.com/github/srishi-vp/Rishi/blob/main/NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
text="Hi i am Rishitha. How are uh. and , how about ur day "
output1 = word_tokenize(text)
output2 = sent_tokenize(text)
print(output1)
print(output2)
# Out:
# ['Hi', 'i', 'am', 'Rishitha', '.', 'How', 'are', 'uh', '.', 'and', ',', 'how', 'about', 'ur', 'day']
# ['Hi i am Rishitha.', 'How are uh.', 'and , how about ur day']

# %%
# !pip install -U spacy

# %%
# !Python -m download em_core_web_sm
# Out:
# /bin/bash: line 1: Python: command not found

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
input = "This is the second session"
doc = nlp(input)

# %%
for token in doc:
  print(token)
# Out:
# This
# is
# the
# second
# session

# %%
for sent in doc.sents:
  print(sent)
# Out:
# This is the second session
