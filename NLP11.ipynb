# %% [markdown]
# <a href="https://colab.research.google.com/github/srishi-vp/Rishi/blob/main/NLP11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================================
# STEP 1: Install Required Libraries
# =========================================
# !pip install nltk textblob sumy

# =========================================
# STEP 2: Import Libraries
# =========================================
import nltk
from textblob import TextBlob
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lsa import LsaSummarizer

# =========================================
# STEP 3: Download NLTK Data
# =========================================
nltk.download('punkt')
nltk.download('punkt_tab') # Added to resolve LookupError

# =========================================
# PART 1: SENTIMENT ANALYSIS
# =========================================
print("\n===== SENTIMENT ANALYSIS =====\n")

tweets = [
    "I love this product! It's amazing 😍",
    "This is the worst service ever.",
    "The movie was okay, not great but not bad.",
    "I am very happy with the results!",
    "I hate waiting in long queues 😡",
    "The food was delicious and fresh!",
    "Not satisfied with the quality.",
    "It's just average, nothing special."
]

for i, tweet in enumerate(tweets):
    analysis = TextBlob(tweet)
    polarity = analysis.sentiment.polarity

    if polarity > 0:
        sentiment = "Positive"
    elif polarity < 0:
        sentiment = "Negative"
    else:
        sentiment = "Neutral"

    print(f"Tweet {i+1}: {tweet}")
    print(f"Sentiment: {sentiment}")
    print(f"Polarity Score: {polarity}")
    print("-" * 50)

# =========================================
# PART 2: TEXT SUMMARIZATION
# =========================================
print("\n===== TEXT SUMMARIZATION =====\n")

text = """
Natural Language Processing is a field of artificial intelligence that focuses on the interaction between computers and humans through natural language.
It enables machines to understand, interpret, and generate human language in a meaningful way.
NLP combines computational linguistics with machine learning and deep learning techniques.
Applications of NLP include sentiment analysis, chatbots, machine translation, and speech recognition.
It is widely used in real-world systems such as virtual assistants, search engines, and recommendation systems.
With the growth of data, NLP is becoming increasingly important in extracting useful information from text.
"""

parser = PlaintextParser.from_string(text, Tokenizer("english"))
summarizer = LsaSummarizer()

summary = summarizer(parser.document, 3)

print("Original Text:\n")
print(text)

print("\nSummary:\n")
for sentence in summary:
    print(sentence)
# Out:
# ...
#
# ===== SENTIMENT ANALYSIS =====
#
# Tweet 1: I love this product! It's amazing 😍
# Sentiment: Positive
# Polarity Score: 0.6125
# --------------------------------------------------
# Tweet 2: This is the worst service ever.
# Sentiment: Negative
# Polarity Score: -1.0
# --------------------------------------------------
# Tweet 3: The movie was okay, not great but not bad.
# Sentiment: Positive
# Polarity Score: 0.14999999999999997
# --------------------------------------------------
# Tweet 4: I am very happy with the results!
# Sentiment: Positive
# Polarity Score: 1.0
# --------------------------------------------------
# Tweet 5: I hate waiting in long queues 😡
# Sentiment: Negative
# Polarity Score: -0.42500000000000004
# --------------------------------------------------
# Tweet 6: The food was delicious and fresh!
# Sentiment: Positive
# Polarity Score: 0.6875
# --------------------------------------------------
# Tweet 7: Not satisfied with the quality.
# ...
